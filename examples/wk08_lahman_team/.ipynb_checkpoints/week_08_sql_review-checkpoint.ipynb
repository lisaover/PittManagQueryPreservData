# %% [markdown]
# ## CMPINF 2110 Spring 2021 - Week 08
#
# Review Pandas and SQL related operations for manipulating, accessing, and building relational models.

# %% [markdown]
# ## Import Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ## Read in the Batting Table

# %% [markdown]
# The data we will work with is a small subset of the complete Lahman package data set.
#
# https://cran.r-project.org/web/packages/Lahman/index.html

# %%
batting = pd.read_csv( 'lahman_batting_table_nlcentral.csv' )

# %%
batting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   playerID  295 non-null    object
#  1   yearID    295 non-null    int64
#  2   lgID      295 non-null    object
#  3   teamID    295 non-null    object
#  4   stint     295 non-null    int64
#  5   G         295 non-null    int64
#  6   AB        295 non-null    int64
#  7   H         295 non-null    int64
#  8   HR        295 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 20.9+ KB

# %%
batting.isna().sum()
# Out:
# playerID    0
# yearID      0
# lgID        0
# teamID      0
# stint       0
# G           0
# AB          0
# H           0
# HR          0
# dtype: int64

# %%
batting.dtypes
# Out:
# playerID    object
# yearID       int64
# lgID        object
# teamID      object
# stint        int64
# G            int64
# AB           int64
# H            int64
# HR           int64
# dtype: object

# %%
batting.head()
# Out:
#     playerID  yearID lgID teamID  stint   G   AB   H  HR
# 0  adducji02    2019   NL    CHN      1   2    5   0   0
# 1  agrazda01    2019   NL    PIT      1  15   22   2   0
# 2  aguilje01    2019   NL    MIL      1  94  222  50   8
# 3  aguilje01    2019   AL    TBA      2  37   92  24   4
# 4  alanirj01    2019   AL    SEA      1   4    0   0   0

# %%
batting.tail()
# Out:
#       playerID  yearID lgID teamID  stint    G   AB    H  HR
# 290   woodal02    2019   NL    CIN      1    7    9    2   0
# 291  woodrbr01    2019   NL    MIL      1   27   45   12   0
# 292  yelicch01    2019   NL    MIL      1  130  489  161  44
# 293  zagunma01    2019   NL    CHN      1   30   36    9   0
# 294  zobribe01    2019   NL    CHN      1   47  150   39   1

# %% [markdown]
# The number of unique values for each column in the data set.

# %%
batting.nunique()
# Out:
# playerID    245
# yearID        1
# lgID          2
# teamID       24
# stint         3
# G           108
# AB          137
# H            75
# HR           34
# dtype: int64

# %%
batting.shape
# Out:
# (295, 9)

# %% [markdown]
# What are the unique values for `playerID` and how many rows are associated with each value?

# %%
batting.playerID.value_counts()
# Out:
# austity01    3
# josepco01    3
# maldoma01    3
# mejiaad01    3
# kinghni01    2
#             ..
# martija03    1
# reynobr01    1
# robindr01    1
# housead01    1
# pinama01     1
# Name: playerID, Length: 245, dtype: int64

# %%
batting.playerID.value_counts().value_counts()
# Out:
# 1    199
# 2     42
# 3      4
# Name: playerID, dtype: int64

# %%
batting.groupby(['playerID']).size().reset_index(name='num_rows')
# Out:
#       playerID  num_rows
# 0    adducji02         1
# 1    agrazda01         1
# 2    aguilje01         2
# 3    alanirj01         2
# 4    alberma01         1
# ..         ...       ...
# 240   woodal02         1
# 241  woodrbr01         1
# 242  yelicch01         1
# 243  zagunma01         1
# 244  zobribe01         1
#
# [245 rows x 2 columns]

# %%
batting.groupby(['playerID']).size().reset_index(name='num_rows').sort_values(['num_rows'], ascending=False)
# Out:
#       playerID  num_rows
# 121  josepco01         3
# 142  maldoma01         3
# 12   austity01         3
# 152  mejiaad01         3
# 68   fariaja01         2
# ..         ...       ...
# 96   haderjo01         1
# 97   hamelco01         1
# 98    happia01         1
# 100  hartlge01         1
# 244  zobribe01         1
#
# [245 rows x 2 columns]

# %%
batting.teamID.value_counts()
# Out:
# PIT    54
# CHN    52
# MIL    50
# CIN    47
# SLN    43
# SFN    10
# KCA     4
# PHI     3
# SEA     3
# TOR     3
# CLE     3
# OAK     3
# LAA     3
# TBA     2
# SDN     2
# MIN     2
# ATL     2
# NYN     2
# HOU     2
# BOS     1
# BAL     1
# DET     1
# LAN     1
# NYA     1
# Name: teamID, dtype: int64

# %%
batting.lgID.value_counts()
# Out:
# NL    266
# AL     29
# Name: lgID, dtype: int64

# %%
batting.yearID.value_counts()
# Out:
# 2019    295
# Name: yearID, dtype: int64

# %% [markdown]
# Identify what represents a single row in the DataFrame.

# %%
batting.groupby(['playerID', 'teamID', 'lgID', 'yearID']).\
size().\
reset_index(name='num_rows')
# Out:
#       playerID teamID lgID  yearID  num_rows
# 0    adducji02    CHN   NL    2019         1
# 1    agrazda01    PIT   NL    2019         1
# 2    aguilje01    MIL   NL    2019         1
# 3    aguilje01    TBA   AL    2019         1
# 4    alanirj01    CIN   NL    2019         1
# ..         ...    ...  ...     ...       ...
# 290   woodal02    CIN   NL    2019         1
# 291  woodrbr01    MIL   NL    2019         1
# 292  yelicch01    MIL   NL    2019         1
# 293  zagunma01    CHN   NL    2019         1
# 294  zobribe01    CHN   NL    2019         1
#
# [295 rows x 5 columns]

# %%
batting.groupby(['playerID', 'teamID', 'lgID', 'yearID']).\
size().\
reset_index(name='num_rows').\
num_rows.\
value_counts()
# Out:
# 1    295
# Name: num_rows, dtype: int64

# %% [markdown]
# What's going on with the `stint` variable in the data set?
#
# Review grouping and aggregating in Pandas.

# %%
batting.groupby(['playerID', 'yearID']).\
aggregate(num_rows = ('H', 'size'),
          num_nonmissings = ('H', 'count'), 
          num_teams = ('teamID', 'nunique'),
          num_stints = ('stint', 'nunique'),
          the_teams = ('teamID', 'unique'),
          the_stints = ('stint', 'unique')).\
reset_index()
# Out:
#       playerID  yearID  num_rows  num_nonmissings  num_teams  num_stints  \
# 0    adducji02    2019         1                1          1           1
# 1    agrazda01    2019         1                1          1           1
# 2    aguilje01    2019         2                2          2           2
# 3    alanirj01    2019         2                2          2           2
# 4    alberma01    2019         1                1          1           1
# ..         ...     ...       ...              ...        ...         ...
# 240   woodal02    2019         1                1          1           1
# 241  woodrbr01    2019         1                1          1           1
# 242  yelicch01    2019         1                1          1           1
# 243  zagunma01    2019         1                1          1           1
# 244  zobribe01    2019         1                1          1           1
#
#       the_teams the_stints
# 0         [CHN]        [1]
# 1         [PIT]        [1]
# 2    [MIL, TBA]     [1, 2]
# 3    [SEA, CIN]     [1, 2]
# 4         [MIL]        [1]
# ..          ...        ...
# 240       [CIN]        [1]
# 241       [MIL]        [1]
# 242       [MIL]        [1]
# 243       [CHN]        [1]
# 244       [CHN]        [1]
#
# [245 rows x 8 columns]

# %%
batting.groupby(['playerID', 'yearID']).\
aggregate(num_rows = ('H', 'size'),
          num_nonmissings = ('H', 'count'), 
          num_teams = ('teamID', 'nunique'),
          num_stints = ('stint', 'nunique'),
          the_teams = ('teamID', 'unique'),
          the_stints = ('stint', 'unique')).\
reset_index().\
groupby(['num_teams', 'num_stints']).\
size().\
reset_index(name='num_players')
# Out:
#    num_teams  num_stints  num_players
# 0          1           1          199
# 1          2           2           42
# 2          3           3            4

# %%
player_summary_in_year = batting.groupby(['playerID', 'yearID']).\
aggregate(num_rows = ('H', 'size'),
          num_nonmissing = ('H', 'count'),
          num_teams = ('teamID', 'nunique'),
          num_stints = ('stint', 'nunique'),
          num_league = ('lgID', 'nunique'),
          num_games = ('G', 'sum'),
          num_hits = ('H', 'sum'),
          num_atbats = ('AB', 'sum'),
          num_homeruns = ('HR', 'sum')).\
reset_index()

# %%
player_summary_in_year
# Out:
#       playerID  yearID  num_rows  num_nonmissing  num_teams  num_stints  \
# 0    adducji02    2019         1               1          1           1
# 1    agrazda01    2019         1               1          1           1
# 2    aguilje01    2019         2               2          2           2
# 3    alanirj01    2019         2               2          2           2
# 4    alberma01    2019         1               1          1           1
# ..         ...     ...       ...             ...        ...         ...
# 240   woodal02    2019         1               1          1           1
# 241  woodrbr01    2019         1               1          1           1
# 242  yelicch01    2019         1               1          1           1
# 243  zagunma01    2019         1               1          1           1
# 244  zobribe01    2019         1               1          1           1
#
#      num_league  num_games  num_hits  num_atbats  num_homeruns
# 0             1          2         0           5             0
# 1             1         15         2          22             0
# 2             2        131        74         314            12
# 3             2         12         1           1             0
# 4             1         67         0           0             0
# ..          ...        ...       ...         ...           ...
# 240           1          7         2           9             0
# 241           1         27        12          45             0
# 242           1        130       161         489            44
# 243           1         30         9          36             0
# 244           1         47        39         150             1
#
# [245 rows x 11 columns]

# %% [markdown]
# ## Read in the player information table

# %%
player_info = pd.read_csv( 'lahman_people_table_nlcentral.csv' )

# %%
player_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   playerID   245 non-null    object
#  1   nameLast   245 non-null    object
#  2   nameFirst  245 non-null    object
#  3   nameGiven  245 non-null    object
#  4   birthDate  245 non-null    object
#  5   debut      245 non-null    object
#  6   finalGame  245 non-null    object
#  7   bats       245 non-null    object
#  8   throws     245 non-null    object
# dtypes: object(9)
# memory usage: 17.4+ KB

# %%
player_info
# Out:
#       playerID  nameLast  nameFirst          nameGiven   birthDate  \
# 0    adducji02    Adduci        Jim        Jim Charles  1985-05-15
# 1    agrazda01   Agrazal      Dario       Dario Abdiel  1994-12-28
# 2    aguilje01   Aguilar      Jesus    Jesus Alexander  1990-06-30
# 3    alanirj01    Alaniz      R. J.              Ruben  1991-06-14
# 4    alberma01    Albers       Matt      Matthew James  1983-01-20
# ..         ...       ...        ...                ...         ...
# 240   woodal02      Wood       Alex   Robert Alexander  1991-01-12
# 241  woodrbr01  Woodruff    Brandon       Brandon Kyle  1993-02-10
# 242  yelicch01    Yelich  Christian  Christian Stephen  1991-12-05
# 243  zagunma01   Zagunis       Mark       Mark Raymond  1993-02-05
# 244  zobribe01   Zobrist        Ben    Benjamin Thomas  1981-05-26
#
#           debut   finalGame bats throws
# 0    2013-09-01  2019-06-01    L      L
# 1    2019-06-15  2019-09-25    R      R
# 2    2014-05-15  2019-09-29    R      R
# 3    2019-04-12  2019-09-28    R      R
# 4    2006-07-25  2019-09-28    L      R
# ..          ...         ...  ...    ...
# 240  2013-05-30  2019-08-29    R      L
# 241  2017-08-04  2019-09-22    L      R
# 242  2013-07-23  2019-09-10    L      R
# 243  2017-06-22  2019-08-18    R      R
# 244  2006-08-01  2019-09-29    B      R
#
# [245 rows x 9 columns]

# %%
player_info.bats.value_counts()
# Out:
# R    163
# L     66
# B     16
# Name: bats, dtype: int64

# %%
player_info.throws.value_counts()
# Out:
# R    202
# L     43
# Name: throws, dtype: int64

# %% [markdown]
# JOIN the two tables together using the `pd.merge()` function.

# %%
batting_summary_in_year = pd.merge( player_summary_in_year, player_info, on=['playerID'], how='left')

# %%
batting_summary_in_year
# Out:
#       playerID  yearID  num_rows  num_nonmissing  num_teams  num_stints  \
# 0    adducji02    2019         1               1          1           1
# 1    agrazda01    2019         1               1          1           1
# 2    aguilje01    2019         2               2          2           2
# 3    alanirj01    2019         2               2          2           2
# 4    alberma01    2019         1               1          1           1
# ..         ...     ...       ...             ...        ...         ...
# 240   woodal02    2019         1               1          1           1
# 241  woodrbr01    2019         1               1          1           1
# 242  yelicch01    2019         1               1          1           1
# 243  zagunma01    2019         1               1          1           1
# 244  zobribe01    2019         1               1          1           1
#
#      num_league  num_games  num_hits  num_atbats  num_homeruns  nameLast  \
# 0             1          2         0           5             0    Adduci
# 1             1         15         2          22             0   Agrazal
# 2             2        131        74         314            12   Aguilar
# 3             2         12         1           1             0    Alaniz
# 4             1         67         0           0             0    Albers
# ..          ...        ...       ...         ...           ...       ...
# 240           1          7         2           9             0      Wood
# 241           1         27        12          45             0  Woodruff
# 242           1        130       161         489            44    Yelich
# 243           1         30         9          36             0   Zagunis
# 244           1         47        39         150             1   Zobrist
#
#      nameFirst          nameGiven   birthDate       debut   finalGame bats  \
# 0          Jim        Jim Charles  1985-05-15  2013-09-01  2019-06-01    L
# 1        Dario       Dario Abdiel  1994-12-28  2019-06-15  2019-09-25    R
# 2        Jesus    Jesus Alexander  1990-06-30  2014-05-15  2019-09-29    R
# 3        R. J.              Ruben  1991-06-14  2019-04-12  2019-09-28    R
# 4         Matt      Matthew James  1983-01-20  2006-07-25  2019-09-28    L
# ..         ...                ...         ...         ...         ...  ...
# 240       Alex   Robert Alexander  1991-01-12  2013-05-30  2019-08-29    R
# 241    Brandon       Brandon Kyle  1993-02-10  2017-08-04  2019-09-22    L
# 242  Christian  Christian Stephen  1991-12-05  2013-07-23  2019-09-10    L
# 243       Mark       Mark Raymond  1993-02-05  2017-06-22  2019-08-18    R
# 244        Ben    Benjamin Thomas  1981-05-26  2006-08-01  2019-09-29    B
#
#     throws
# 0        L
# 1        R
# 2        R
# 3        R
# 4        R
# ..     ...
# 240      L
# 241      R
# 242      R
# 243      R
# 244      R
#
# [245 rows x 19 columns]

# %% [markdown]
# How can we calculate the age of a player?

# %%
batting_summary_in_year.dtypes
# Out:
# playerID          object
# yearID             int64
# num_rows           int64
# num_nonmissing     int64
# num_teams          int64
# num_stints         int64
# num_league         int64
# num_games          int64
# num_hits           int64
# num_atbats         int64
# num_homeruns       int64
# nameLast          object
# nameFirst         object
# nameGiven         object
# birthDate         object
# debut             object
# finalGame         object
# bats              object
# throws            object
# dtype: object

# %% [markdown]
# First convert the dates from strings to datetime objects.

# %%
batting_summary_in_year['birth_date_dt'] = pd.to_datetime( batting_summary_in_year.birthDate )

# %%
batting_summary_in_year['birth_year'] = batting_summary_in_year.birth_date_dt.dt.year

# %%
batting_summary_in_year
# Out:
#       playerID  yearID  num_rows  num_nonmissing  num_teams  num_stints  \
# 0    adducji02    2019         1               1          1           1
# 1    agrazda01    2019         1               1          1           1
# 2    aguilje01    2019         2               2          2           2
# 3    alanirj01    2019         2               2          2           2
# 4    alberma01    2019         1               1          1           1
# ..         ...     ...       ...             ...        ...         ...
# 240   woodal02    2019         1               1          1           1
# 241  woodrbr01    2019         1               1          1           1
# 242  yelicch01    2019         1               1          1           1
# 243  zagunma01    2019         1               1          1           1
# 244  zobribe01    2019         1               1          1           1
#
#      num_league  num_games  num_hits  num_atbats  ...  nameLast  nameFirst  \
# 0             1          2         0           5  ...    Adduci        Jim
# 1             1         15         2          22  ...   Agrazal      Dario
# 2             2        131        74         314  ...   Aguilar      Jesus
# 3             2         12         1           1  ...    Alaniz      R. J.
# 4             1         67         0           0  ...    Albers       Matt
# ..          ...        ...       ...         ...  ...       ...        ...
# 240           1          7         2           9  ...      Wood       Alex
# 241           1         27        12          45  ...  Woodruff    Brandon
# 242           1        130       161         489  ...    Yelich  Christian
# 243           1         30         9          36  ...   Zagunis       Mark
# 244           1         47        39         150  ...   Zobrist        Ben
#
#              nameGiven   birthDate       debut   finalGame bats throws  \
# 0          Jim Charles  1985-05-15  2013-09-01  2019-06-01    L      L
# 1         Dario Abdiel  1994-12-28  2019-06-15  2019-09-25    R      R
# 2      Jesus Alexander  1990-06-30  2014-05-15  2019-09-29    R      R
# 3                Ruben  1991-06-14  2019-04-12  2019-09-28    R      R
# 4        Matthew James  1983-01-20  2006-07-25  2019-09-28    L      R
# ..                 ...         ...         ...         ...  ...    ...
# 240   Robert Alexander  1991-01-12  2013-05-30  2019-08-29    R      L
# 241       Brandon Kyle  1993-02-10  2017-08-04  2019-09-22    L      R
# 242  Christian Stephen  1991-12-05  2013-07-23  2019-09-10    L      R
# 243       Mark Raymond  1993-02-05  2017-06-22  2019-08-18    R      R
# 244    Benjamin Thomas  1981-05-26  2006-08-01  2019-09-29    B      R
#
#     birth_date_dt birth_year
# 0      1985-05-15       1985
# 1      1994-12-28       1994
# 2      1990-06-30       1990
# 3      1991-06-14       1991
# 4      1983-01-20       1983
# ..            ...        ...
# 240    1991-01-12       1991
# 241    1993-02-10       1993
# 242    1991-12-05       1991
# 243    1993-02-05       1993
# 244    1981-05-26       1981
#
# [245 rows x 21 columns]

# %% [markdown]
# Calculate the age of each player in the year 2019.

# %%
batting_summary_in_year['player_age'] = batting_summary_in_year.yearID - batting_summary_in_year.birth_year

# %%
batting_summary_in_year
# Out:
#       playerID  yearID  num_rows  num_nonmissing  num_teams  num_stints  \
# 0    adducji02    2019         1               1          1           1
# 1    agrazda01    2019         1               1          1           1
# 2    aguilje01    2019         2               2          2           2
# 3    alanirj01    2019         2               2          2           2
# 4    alberma01    2019         1               1          1           1
# ..         ...     ...       ...             ...        ...         ...
# 240   woodal02    2019         1               1          1           1
# 241  woodrbr01    2019         1               1          1           1
# 242  yelicch01    2019         1               1          1           1
# 243  zagunma01    2019         1               1          1           1
# 244  zobribe01    2019         1               1          1           1
#
#      num_league  num_games  num_hits  num_atbats  ...  nameFirst  \
# 0             1          2         0           5  ...        Jim
# 1             1         15         2          22  ...      Dario
# 2             2        131        74         314  ...      Jesus
# 3             2         12         1           1  ...      R. J.
# 4             1         67         0           0  ...       Matt
# ..          ...        ...       ...         ...  ...        ...
# 240           1          7         2           9  ...       Alex
# 241           1         27        12          45  ...    Brandon
# 242           1        130       161         489  ...  Christian
# 243           1         30         9          36  ...       Mark
# 244           1         47        39         150  ...        Ben
#
#              nameGiven   birthDate       debut   finalGame bats throws  \
# 0          Jim Charles  1985-05-15  2013-09-01  2019-06-01    L      L
# 1         Dario Abdiel  1994-12-28  2019-06-15  2019-09-25    R      R
# 2      Jesus Alexander  1990-06-30  2014-05-15  2019-09-29    R      R
# 3                Ruben  1991-06-14  2019-04-12  2019-09-28    R      R
# 4        Matthew James  1983-01-20  2006-07-25  2019-09-28    L      R
# ..                 ...         ...         ...         ...  ...    ...
# 240   Robert Alexander  1991-01-12  2013-05-30  2019-08-29    R      L
# 241       Brandon Kyle  1993-02-10  2017-08-04  2019-09-22    L      R
# 242  Christian Stephen  1991-12-05  2013-07-23  2019-09-10    L      R
# 243       Mark Raymond  1993-02-05  2017-06-22  2019-08-18    R      R
# 244    Benjamin Thomas  1981-05-26  2006-08-01  2019-09-29    B      R
#
#     birth_date_dt birth_year player_age
# 0      1985-05-15       1985         34
# 1      1994-12-28       1994         25
# 2      1990-06-30       1990         29
# 3      1991-06-14       1991         28
# 4      1983-01-20       1983         36
# ..            ...        ...        ...
# 240    1991-01-12       1991         28
# 241    1993-02-10       1993         26
# 242    1991-12-05       1991         28
# 243    1993-02-05       1993         26
# 244    1981-05-26       1981         38
#
# [245 rows x 22 columns]

# %% [markdown]
# What's the relationship between the number of homeruns hit in a season and the age of a player?

# %%
sns.set_style('whitegrid')

sns.relplot(data = batting_summary_in_year, x='player_age', y='num_homeruns', s=100, aspect=2)

plt.show()

# %%
sns.catplot(data = batting_summary_in_year, x='player_age', y='num_homeruns', kind='strip', s=7, aspect=2)

plt.show()

# %% [markdown]
# Find a player on the Pittsburgh Pirates. I can't use the summarized table to do that!

# %%
batting
# Out:
#       playerID  yearID lgID teamID  stint    G   AB    H  HR
# 0    adducji02    2019   NL    CHN      1    2    5    0   0
# 1    agrazda01    2019   NL    PIT      1   15   22    2   0
# 2    aguilje01    2019   NL    MIL      1   94  222   50   8
# 3    aguilje01    2019   AL    TBA      2   37   92   24   4
# 4    alanirj01    2019   AL    SEA      1    4    0    0   0
# ..         ...     ...  ...    ...    ...  ...  ...  ...  ..
# 290   woodal02    2019   NL    CIN      1    7    9    2   0
# 291  woodrbr01    2019   NL    MIL      1   27   45   12   0
# 292  yelicch01    2019   NL    MIL      1  130  489  161  44
# 293  zagunma01    2019   NL    CHN      1   30   36    9   0
# 294  zobribe01    2019   NL    CHN      1   47  150   39   1
#
# [295 rows x 9 columns]

# %%
batting.loc[ batting.teamID.isin(['PIT']), :]
# Out:
#       playerID  yearID lgID teamID  stint    G   AB    H  HR
# 1    agrazda01    2019   NL    PIT      1   15   22    2   0
# 11   archech01    2019   NL    PIT      1   23   35    4   0
# 23   baronst01    2019   NL    PIT      1    7   10    2   0
# 26    belljo02    2019   NL    PIT      1  143  527  146  37
# 34   braulst01    2019   NL    PIT      1   34   42   14   1
# 38   burdini01    2019   NL    PIT      1   11    0    0   0
# 41   cabreme01    2019   NL    PIT      1  133  378  106   7
# 50   cervefr01    2019   NL    PIT      1   34  109   21   1
# 60   crickky01    2019   NL    PIT      1   52    0    0   0
# 63   davisro03    2019   NL    PIT      1    5    1    0   0
# 68    diazel01    2019   NL    PIT      1  101  303   73   2
# 69   dickeco01    2019   NL    PIT      1   44  127   40   4
# 75   durapmo01    2019   NL    PIT      1   14    4    1   0
# 79   elmorja01    2019   NL    PIT      1   20   47   10   0
# 81   escoblu01    2019   NL    PIT      1    4    2    0   0
# 85   felizmi01    2019   NL    PIT      1   58    0    0   0
# 89   fraziad01    2019   NL    PIT      1  152  554  154  10
# 106  gonzaer01    2019   NL    PIT      1   53  142   36   1
# 122  hartlge01    2019   NL    PIT      1   29    0    0   0
# 133  holmecl01    2019   NL    PIT      1   35    5    0   0
# 145  jerezwi01    2019   NL    PIT      2    6    0    0   0
# 148  josepco01    2019   NL    PIT      3    9   11    2   0
# 149   kangju01    2019   NL    PIT      1   65  172   29  10
# 150   kelake01    2019   NL    PIT      1   32    0    0   0
# 151  kellemi03    2019   NL    PIT      1   11   10    0   0
# 156  kinghni01    2019   NL    PIT      1   14    6    0   0
# 160  krameke01    2019   NL    PIT      1   22   42    7   0
# 165  liriafr01    2019   NL    PIT      1   69    1    1   0
# 169  lylesjo01    2019   NL    PIT      1   17   25    2   0
# 171  lyonsty01    2019   NL    PIT      1    3    1    0   0
# 179  markepa01    2019   NL    PIT      2   15    3    0   0
# 180  martest01    2019   NL    PIT      1  132  539  159  23
# 182  martija03    2019   NL    PIT      1   20   36    9   0
# 184  marveja01    2019   NL    PIT      1    4    4    0   0
# 186  mcraeal01    2019   NL    PIT      1   11    6    2   0
# 197  moranco01    2019   NL    PIT      1  149  466  129  13
# 200  musgrjo01    2019   NL    PIT      1   46   51    8   0
# 202  neverdo01    2019   NL    PIT      1   10    0    0   0
# 203  newmake01    2019   NL    PIT      1  130  493  152  12
# 208  osunajo01    2019   NL    PIT      1   95  261   69  10
# 219  polangr01    2019   NL    PIT      1   42  153   37   6
# 227  ramirye01    2019   NL    PIT      2    9    2    0   0
# 231  reyespa01    2019   NL    PIT      1   71  143   29   2
# 232  reynobr01    2019   NL    PIT      1  134  491  154  16
# 234   riosya01    2019   NL    PIT      2   10    0    0   0
# 235  riverfe01    2019   NL    PIT      1   56    2    0   0
# 240  rodriri05    2019   NL    PIT      1   72    0    0   0
# 252  shuckja01    2019   NL    PIT      1   27   47   10   0
# 258  stallja01    2019   NL    PIT      1   71  191   50   6
# 261  stratch01    2019   NL    PIT      2   28    2    0   0
# 265  taillja01    2019   NL    PIT      1    7    8    2   0
# 269  tuckeco01    2019   NL    PIT      1   56  147   31   2
# 276   wangwe01    2019   NL    PIT      2    5    0    0   0
# 286  willitr01    2019   NL    PIT      1   26   36    6   0

# %% [markdown]
# ## Read in the team information

# %%
team_info = pd.read_csv( 'lahman_team_table.csv' )

# %%
team_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lgID       30 non-null     object
#  1   teamID     30 non-null     object
#  2   team_name  30 non-null     object
# dtypes: object(3)
# memory usage: 848.0+ bytes

# %%
team_info
# Out:
#    lgID teamID                      team_name
# 0    NL    ARI           Arizona Diamondbacks
# 1    NL    ATL                 Atlanta Braves
# 2    AL    BAL              Baltimore Orioles
# 3    AL    BOS                 Boston Red Sox
# 4    AL    CHA              Chicago White Sox
# 5    NL    CHN                   Chicago Cubs
# 6    NL    CIN                Cincinnati Reds
# 7    AL    CLE              Cleveland Indians
# 8    NL    COL               Colorado Rockies
# 9    AL    DET                 Detroit Tigers
# 10   AL    HOU                 Houston Astros
# 11   AL    KCA             Kansas City Royals
# 12   AL    LAA  Los Angeles Angels of Anaheim
# 13   NL    LAN            Los Angeles Dodgers
# 14   NL    MIA                Florida Marlins
# 15   NL    MIL              Milwaukee Brewers
# 16   AL    MIN                Minnesota Twins
# 17   AL    NYA               New York Yankees
# 18   NL    NYN                  New York Mets
# 19   AL    OAK              Oakland Athletics
# 20   NL    PHI          Philadelphia Phillies
# 21   NL    PIT             Pittsburgh Pirates
# 22   NL    SDN               San Diego Padres
# 23   AL    SEA               Seattle Mariners
# 24   NL    SFN           San Francisco Giants
# 25   NL    SLN            St. Louis Cardinals
# 26   AL    TBA                 Tampa Bay Rays
# 27   AL    TEX                  Texas Rangers
# 28   AL    TOR              Toronto Blue Jays
# 29   NL    WAS           Washington Nationals

# %% [markdown]
# Count the number of times a particular character occurs in a string. Specifically, we might be interested in splitting by a whitespace, `' '`, so how many whitespaces are there in the `team_name`?

# %%
team_info.team_name.str.count(' ')
# Out:
# 0     1
# 1     1
# 2     1
# 3     2
# 4     2
# 5     1
# 6     1
# 7     1
# 8     1
# 9     1
# 10    1
# 11    2
# 12    4
# 13    2
# 14    1
# 15    1
# 16    1
# 17    2
# 18    2
# 19    1
# 20    1
# 21    1
# 22    2
# 23    1
# 24    2
# 25    2
# 26    2
# 27    1
# 28    2
# 29    1
# Name: team_name, dtype: int64

# %%
team_info.team_name.str.count(' ').value_counts()
# Out:
# 1    18
# 2    11
# 4     1
# Name: team_name, dtype: int64
